# %%
# !pip install pandas

# %%
import pandas as pd

# %%
##series = it is a one dimensional array type object

# %%
data = [1,2,3,4,5]
series = pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#create a series from dictionary elements
data = {'a':1,'v':2}
series_dict = pd.Series(data)
print(series_dict)
# Out:
# a    1
# v    2
# dtype: int64

# %%
data = [10,20,30]
index = ['a','b','c']
pd.Series(data,index = index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
##data frame = multidimensional arrays
## create a dataframe from a dictionary of list

data = {
    'Name' : ['krish','john','jack'],
    'age':[12,34,45],
    'town':['bbsr','bam','banglore']
}

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  age      town
# 0  krish   12      bbsr
# 1   john   34       bam
# 2   jack   45  banglore
# <class 'pandas.core.frame.DataFrame'>

# %%
# !pip install numpy
import numpy as np
np.array(df)
# Out:
# ...
# array([['krish', 12, 'bbsr'],
#        ['john', 34, 'bam'],
#        ['jack', 45, 'banglore']], dtype=object)

# %%
## create a dataframe from a list of dictionaries
data = [
    {'name':'krish','age':32,'city':'banglore'},
    {'name':'radha','age':22,'city':'bulore'},
    {'name':'bheem','age':12,'city':'kanouore'},
]

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     name  age      city
# 0  krish   32  banglore
# 1  radha   22    bulore
# 2  bheem   12  kanouore
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.read_csv('crop_yield.csv')

# %%
df.tail(5)
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide     Yield
# 19684        2000           1498.0    395200.00    1160.00  0.500000
# 19685        3000           1498.0     98800.00     290.00  3.000000
# 19686      440900           1356.2  29586735.11   96373.73  1.285000
# 19687        5488           1356.2  26242746.82   85481.26  0.016667
# 19688      392160           1356.2  22778368.48   74196.64  1.261818

# %%
print(df.head(5))
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
df.describe()
# Out:
#           Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# ...

# %%
data
# Out:
# [{'name': 'krish', 'age': 32, 'city': 'banglore'},
#  {'name': 'radha', 'age': 22, 'city': 'bulore'},
#  {'name': 'bheem', 'age': 12, 'city': 'kanouore'}]

# %%
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
df = data

# %%
data = [
    {'name': 'Krish', 'age': 32, 'city': 'Bangalore'},
    {'name': 'John', 'age': 34, 'city': 'ore'},
    {'name': 'Jack', 'age': 32, 'city': 'Bangae'}
]
df = pd.DataFrame(data)
print(df)
# Out:
#     name  age       city
# 0  Krish   32  Bangalore
# 1   John   34        ore
# 2   Jack   32     Bangae

# %%
df['name']
# Out:
# 0    Krish
# 1     John
# 2     Jack
# Name: name, dtype: object

# %%
df.iloc[0]
# Out:
# name        Krish
# age            32
# city    Bangalore
# Name: 0, dtype: object

# %%
df.loc[0][0]
# Out:
# C:\Users\smrut\AppData\Local\Temp\ipykernel_4324\2552443799.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][0]
# 'Krish'

# %%
##iloc stands for index location and 
##loc for just location

# %%
##accesing a specified elements
df.at[2,'name']
# Out:
# 'Jack'

# %%
df.iat[2,2]
# Out:
# 'Bangae'

# %%
#adding a column
df['salary']=[2000,300,4500]
df
# Out:
#     name  age       city  salary
# 0  Krish   32  Bangalore    2000
# 1   John   34        ore     300
# 2   Jack   32     Bangae    4500

# %%
df.drop('salary',axis=1)
# Out:
#     name  age       city
# 0  Krish   32  Bangalore
# 1   John   34        ore
# 2   Jack   32     Bangae

# %%
df
# Out:
#     name  age       city  salary
# 0  Krish   32  Bangalore    2000
# 1   John   34        ore     300
# 2   Jack   32     Bangae    4500

# %%
df.drop('salary',axis = 1,inplace = True)
##to make it permanently delete, we add inplace
df
# Out:
#     name  age       city
# 0  Krish   32  Bangalore
# 1   John   34        ore
# 2   Jack   32     Bangae

# %%
## add age to the column
df['age']=df['age']+1
df
# Out:
#     name  age       city
# 0  Krish   33  Bangalore
# 1   John   35        ore
# 2   Jack   33     Bangae

# %%
df.drop(0)
# Out:
#    name  age    city
# 1  John   35     ore
# 2  Jack   33  Bangae
