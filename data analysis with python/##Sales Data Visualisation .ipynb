# %%
##Sales Data Visualisation
import pandas as pd
sales = pd.read_csv('Groceries_Sales_data.csv')
sales.head(5)
# Out:
#          Date    Sales
# 0  2018-02-01  21199.0
# 1  2018-02-02  10634.0
# 2  2018-02-03   7966.0
# 3  2018-02-04   1353.0
# 4  2018-02-05   9497.0

# %%
##plot total sales by date
total_sales=sales.groupby('Date')['Sales'].sum()

# %%
total_sales.plot(kind='bar', color='teal')
# Out:
# <Axes: xlabel='Date'>
