# %%
a = int(input("enter a number"))
b = int(input("enter a number"))
sum = a + b; difference = a - b;
print("sum is",sum)
print("differnce is:",difference)
c = 1
# Out:
# enter a number 4
# enter a number 5
# sum is 9
# differnce is: -1

# %%
if(c > a and c > b ):
    print("c is greatest")
print("c is not greatest")
# Out:
# c is not greatest

# %%
result = "hello" + str(5)
print(result)
# Out:
# hello5

# %%
str = "hello"
str.isalnum()
# Out:
# True

# %%
str.casefold()
# Out:
# 'hello'

# %%
floor_div_result = 9 // 3
print(floor_div_result)
# Out:
# 3

# %%
n = int(input("Enter a number: "))
ans = 1

for i in range(1, n+1):
    ans *= i

print(ans)
# Out:
# Enter a number:  4
# 24

# %%
a = 4
b= 5
c = a
a= b 
b= c
print(c)
# Out:
# 4

# %%
f = 45
c = 4.5*f + 32
print(c)
# Out:
# 234.5

# %%
x = 10   # change value to test

if isinstance(x, int):
    print("x is an integer")
elif isinstance(x, float):
    print("x is a float")
elif isinstance(x, str):
    print("x is a string")
elif isinstance(x, list):
    print("x is a list")
elif isinstance(x, dict):
    print("x is a dictionary")
else:
    print("Unknown data type")
# Out:
# x is an integer

# %%
s = "smruti"

for i in s:
    print(i)
# Out:
# s
# m
# r
# u
# t
# i

# %%
s = "hello"
rev = ""

for char in s:
    rev = char + rev

print(rev)
# Out:
# olleh
